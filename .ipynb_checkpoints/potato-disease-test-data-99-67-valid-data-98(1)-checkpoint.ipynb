# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2023-06-21 13:55:55.932458: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 13:55:57.318933: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Import Data

# %% [markdown]
# ## File path

# %%
train_dir = "data/Potato/Train"
test_dir = "data/Potato/Test"
valid_dir = "data/Potato/Valid"

# %% [markdown]
# ## Data Rescaling and augmentation

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(224, 224, 3)),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
  tf.keras.layers.experimental.preprocessing.RandomHeight(0.2),
  tf.keras.layers.experimental.preprocessing.RandomWidth(0.2),
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
], name ="data_augmentation")

# %% [markdown]
# ## Load datasets

# %% [markdown]
# ### Shuffle and prefetch

# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = train_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True
).cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = test_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE
).cache().prefetch(buffer_size=tf.data.AUTOTUNE)

valid_datasets = tf.keras.preprocessing.image_dataset_from_directory(
    directory = valid_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE
)

class_names = valid_datasets.class_names
valid_data = valid_datasets.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 900 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.

# %%
[(images, label_batch)] = train_data.take(1)
total_classes = label_batch.shape[-1]
total_classes
# Out:
# 2022-08-13 01:51:50.650324: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 3

# %% [markdown]
# ## Visualizing data

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in train_data.take(1):
    for i in range(0,8):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")

# %% [markdown]
# # Create Checkpoint

# %%
checkpoint_path = "/CheckPoint/cp.ckpt"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    save_weights_only=True,
    monitor='val_accuracy',
    save_best_only=True
)

# %% [markdown]
# # Create model

# %%
model = tf.keras.Sequential([
    data_augmentation,
    tf.keras.layers.Conv2D(60, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(60, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(60, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(total_classes, activation='softmax', name='output_layers')

])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# data_augmentation (Sequentia (None, None, None, 3)     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 60)    1680
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, None, None, 60)    0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 60)    32460
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, None, None, 60)    0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 60)    32460
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, None, None, 60)    0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 60)                0
# _________________________________________________________________
# output_layers (Dense)        (None, 3)                 183
# =================================================================
# Total params: 66,783
# Trainable params: 66,783
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile model

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.Adam(),
    metrics = ['accuracy']
)

# %% [markdown]
# # Fit the model

# %%
history = model.fit(
    train_data,
    epochs=200,
    validation_data = test_data,
    validation_steps = len(test_data),
    callbacks = [
        checkpoint_callback,
    ]
)
# Out:
# Epoch 1/200
# 2022-08-13 01:51:56.621406: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 29/29 [==============================] - 23s 522ms/step - loss: 1.1020 - accuracy: 0.3644 - val_loss: 1.0925 - val_accuracy: 0.3933
# Epoch 2/200
# 29/29 [==============================] - 12s 410ms/step - loss: 1.0726 - accuracy: 0.4000 - val_loss: 1.0079 - val_accuracy: 0.3333
# Epoch 3/200
# 29/29 [==============================] - 11s 394ms/step - loss: 0.9856 - accuracy: 0.4722 - val_loss: 0.9332 - val_accuracy: 0.4167
# Epoch 4/200
# 29/29 [==============================] - 11s 350ms/step - loss: 0.8539 - accuracy: 0.5911 - val_loss: 0.7300 - val_accuracy: 0.6367
# Epoch 5/200
# 29/29 [==============================] - 11s 395ms/step - loss: 0.7316 - accuracy: 0.6667 - val_loss: 0.6106 - val_accuracy: 0.7033
# Epoch 6/200
# 29/29 [==============================] - 11s 375ms/step - loss: 0.6385 - accuracy: 0.7333 - val_loss: 0.5768 - val_accuracy: 0.8100
# Epoch 7/200
# 29/29 [==============================] - 11s 391ms/step - loss: 0.5163 - accuracy: 0.8089 - val_loss: 0.5433 - val_accuracy: 0.7567
# Epoch 8/200
# 29/29 [==============================] - 10s 340ms/step - loss: 0.3606 - accuracy: 0.8767 - val_loss: 0.3264 - val_accuracy: 0.8567
# Epoch 9/200
# 29/29 [==============================] - 10s 349ms/step - loss: 0.3405 - accuracy: 0.8689 - val_loss: 0.4743 - val_accuracy: 0.7967
# Epoch 10/200
# 29/29 [==============================] - 13s 457ms/step - loss: 0.3142 - accuracy: 0.8933 - val_loss: 0.3244 - val_accuracy: 0.8467
# Epoch 11/200
# 29/29 [==============================] - 13s 446ms/step - loss: 0.2899 - accuracy: 0.8933 - val_loss: 0.3131 - val_accuracy: 0.9033
# Epoch 12/200
# 29/29 [==============================] - 11s 392ms/step - loss: 0.2677 - accuracy: 0.8833 - val_loss: 0.2075 - val_accuracy: 0.9200
# Epoch 13/200
# 29/29 [==============================] - 10s 365ms/step - loss: 0.2158 - accuracy: 0.9189 - val_loss: 0.1562 - val_accuracy: 0.9500
# Epoch 14/200
# 29/29 [==============================] - 9s 307ms/step - loss: 0.2040 - accuracy: 0.9256 - val_loss: 0.1617 - val_accuracy: 0.9333
# Epoch 15/200
# 29/29 [==============================] - 9s 319ms/step - loss: 0.2125 - accuracy: 0.9144 - val_loss: 0.1775 - val_accuracy: 0.9300
# Epoch 16/200
# 29/29 [==============================] - 11s 373ms/step - loss: 0.1777 - accuracy: 0.9367 - val_loss: 0.1384 - val_accuracy: 0.9567
# Epoch 17/200
# 29/29 [==============================] - 10s 333ms/step - loss: 0.2116 - accuracy: 0.9156 - val_loss: 0.1842 - val_accuracy: 0.9300
# Epoch 18/200
# 29/29 [==============================] - 9s 279ms/step - loss: 0.1851 - accuracy: 0.9389 - val_loss: 0.1464 - val_accuracy: 0.9433
# Epoch 19/200
# 29/29 [==============================] - 9s 326ms/step - loss: 0.1501 - accuracy: 0.9500 - val_loss: 0.1639 - val_accuracy: 0.9433
# Epoch 20/200
# 29/29 [==============================] - 9s 335ms/step - loss: 0.1548 - accuracy: 0.9411 - val_loss: 0.1997 - val_accuracy: 0.9067
# Epoch 21/200
# 29/29 [==============================] - 10s 336ms/step - loss: 0.1341 - accuracy: 0.9511 - val_loss: 0.1589 - val_accuracy: 0.9400
# Epoch 22/200
# 29/29 [==============================] - 10s 328ms/step - loss: 0.1285 - accuracy: 0.9467 - val_loss: 0.1036 - val_accuracy: 0.9600
# Epoch 23/200
# 29/29 [==============================] - 9s 334ms/step - loss: 0.1443 - accuracy: 0.9456 - val_loss: 0.1412 - val_accuracy: 0.9367
# Epoch 24/200
# 29/29 [==============================] - 10s 331ms/step - loss: 0.1706 - accuracy: 0.9344 - val_loss: 0.1682 - val_accuracy: 0.9333
# Epoch 25/200
# 29/29 [==============================] - 10s 342ms/step - loss: 0.2106 - accuracy: 0.9244 - val_loss: 0.1730 - val_accuracy: 0.9267
# Epoch 26/200
# 29/29 [==============================] - 9s 333ms/step - loss: 0.1361 - accuracy: 0.9511 - val_loss: 0.1896 - val_accuracy: 0.9000
# Epoch 27/200
# 29/29 [==============================] - 7s 255ms/step - loss: 0.1769 - accuracy: 0.9322 - val_loss: 0.1223 - val_accuracy: 0.9433
# Epoch 28/200
# 29/29 [==============================] - 9s 284ms/step - loss: 0.1423 - accuracy: 0.9478 - val_loss: 0.2058 - val_accuracy: 0.8967
# Epoch 29/200
# 29/29 [==============================] - 8s 269ms/step - loss: 0.1640 - accuracy: 0.9344 - val_loss: 0.1286 - val_accuracy: 0.9467
# Epoch 30/200
# 29/29 [==============================] - 7s 263ms/step - loss: 0.1447 - accuracy: 0.9556 - val_loss: 0.1091 - val_accuracy: 0.9600
# Epoch 31/200
# 29/29 [==============================] - 8s 265ms/step - loss: 0.1366 - accuracy: 0.9522 - val_loss: 0.2781 - val_accuracy: 0.8733
# Epoch 32/200
# 29/29 [==============================] - 7s 259ms/step - loss: 0.1494 - accuracy: 0.9456 - val_loss: 0.1665 - val_accuracy: 0.9333
# Epoch 33/200
# 29/29 [==============================] - 9s 287ms/step - loss: 0.1108 - accuracy: 0.9644 - val_loss: 0.0862 - val_accuracy: 0.9633
# Epoch 34/200
# 29/29 [==============================] - 7s 238ms/step - loss: 0.1159 - accuracy: 0.9633 - val_loss: 0.1287 - val_accuracy: 0.9433
# Epoch 35/200
# 29/29 [==============================] - 7s 238ms/step - loss: 0.1969 - accuracy: 0.9222 - val_loss: 0.3393 - val_accuracy: 0.8467
# Epoch 36/200
# 29/29 [==============================] - 8s 253ms/step - loss: 0.1466 - accuracy: 0.9433 - val_loss: 0.1329 - val_accuracy: 0.9500
# Epoch 37/200
# 29/29 [==============================] - 7s 232ms/step - loss: 0.1175 - accuracy: 0.9556 - val_loss: 0.1553 - val_accuracy: 0.9167
# Epoch 38/200
# 29/29 [==============================] - 8s 295ms/step - loss: 0.1210 - accuracy: 0.9578 - val_loss: 0.2801 - val_accuracy: 0.8767
# Epoch 39/200
# 29/29 [==============================] - 8s 277ms/step - loss: 0.1409 - accuracy: 0.9556 - val_loss: 0.0926 - val_accuracy: 0.9600
# Epoch 40/200
# 29/29 [==============================] - 8s 271ms/step - loss: 0.1078 - accuracy: 0.9567 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 41/200
# 29/29 [==============================] - 9s 306ms/step - loss: 0.1020 - accuracy: 0.9644 - val_loss: 0.0773 - val_accuracy: 0.9667
# Epoch 42/200
# 29/29 [==============================] - 8s 268ms/step - loss: 0.1148 - accuracy: 0.9600 - val_loss: 0.2450 - val_accuracy: 0.8800
# Epoch 43/200
# 29/29 [==============================] - 7s 231ms/step - loss: 0.1513 - accuracy: 0.9489 - val_loss: 0.0748 - val_accuracy: 0.9733
# Epoch 44/200
# 29/29 [==============================] - 6s 209ms/step - loss: 0.0911 - accuracy: 0.9700 - val_loss: 0.0660 - val_accuracy: 0.9733
# Epoch 45/200
# 29/29 [==============================] - 8s 287ms/step - loss: 0.0946 - accuracy: 0.9600 - val_loss: 0.0788 - val_accuracy: 0.9667
# Epoch 46/200
# 29/29 [==============================] - 6s 199ms/step - loss: 0.1219 - accuracy: 0.9533 - val_loss: 0.2250 - val_accuracy: 0.9033
# Epoch 47/200
# 29/29 [==============================] - 7s 243ms/step - loss: 0.1397 - accuracy: 0.9467 - val_loss: 0.2426 - val_accuracy: 0.8900
# Epoch 48/200
# 29/29 [==============================] - 8s 257ms/step - loss: 0.1440 - accuracy: 0.9478 - val_loss: 0.0878 - val_accuracy: 0.9667
# Epoch 49/200
# 29/29 [==============================] - 6s 218ms/step - loss: 0.1091 - accuracy: 0.9544 - val_loss: 0.0874 - val_accuracy: 0.9767
# Epoch 50/200
# 29/29 [==============================] - 7s 246ms/step - loss: 0.1022 - accuracy: 0.9600 - val_loss: 0.1221 - val_accuracy: 0.9433
# Epoch 51/200
# 29/29 [==============================] - 8s 265ms/step - loss: 0.0869 - accuracy: 0.9689 - val_loss: 0.0588 - val_accuracy: 0.9833
# Epoch 52/200
# 29/29 [==============================] - 8s 284ms/step - loss: 0.1080 - accuracy: 0.9578 - val_loss: 0.1832 - val_accuracy: 0.9133
# Epoch 53/200
# 29/29 [==============================] - 6s 223ms/step - loss: 0.1126 - accuracy: 0.9589 - val_loss: 0.0644 - val_accuracy: 0.9800
# Epoch 54/200
# 29/29 [==============================] - 9s 299ms/step - loss: 0.1257 - accuracy: 0.9578 - val_loss: 0.0699 - val_accuracy: 0.9733
# Epoch 55/200
# 29/29 [==============================] - 7s 253ms/step - loss: 0.0904 - accuracy: 0.9711 - val_loss: 0.0710 - val_accuracy: 0.9700
# Epoch 56/200
# 29/29 [==============================] - 8s 269ms/step - loss: 0.0913 - accuracy: 0.9622 - val_loss: 0.1577 - val_accuracy: 0.9200
# Epoch 57/200
# 29/29 [==============================] - 6s 223ms/step - loss: 0.1069 - accuracy: 0.9644 - val_loss: 0.1425 - val_accuracy: 0.9367
# Epoch 58/200
# 29/29 [==============================] - 7s 221ms/step - loss: 0.1286 - accuracy: 0.9522 - val_loss: 0.0784 - val_accuracy: 0.9733
# Epoch 59/200
# 29/29 [==============================] - 7s 249ms/step - loss: 0.1173 - accuracy: 0.9544 - val_loss: 0.1515 - val_accuracy: 0.9333
# Epoch 60/200
# 29/29 [==============================] - 7s 230ms/step - loss: 0.0938 - accuracy: 0.9667 - val_loss: 0.0633 - val_accuracy: 0.9833
# Epoch 61/200
# 29/29 [==============================] - 6s 217ms/step - loss: 0.0908 - accuracy: 0.9700 - val_loss: 0.0557 - val_accuracy: 0.9800
# Epoch 62/200
# 29/29 [==============================] - 8s 260ms/step - loss: 0.1051 - accuracy: 0.9533 - val_loss: 0.1800 - val_accuracy: 0.9200
# Epoch 63/200
# 29/29 [==============================] - 6s 214ms/step - loss: 0.1189 - accuracy: 0.9622 - val_loss: 0.0999 - val_accuracy: 0.9533
# Epoch 64/200
# 29/29 [==============================] - 4s 151ms/step - loss: 0.1061 - accuracy: 0.9611 - val_loss: 0.2108 - val_accuracy: 0.9033
# Epoch 65/200
# 29/29 [==============================] - 4s 146ms/step - loss: 0.1070 - accuracy: 0.9622 - val_loss: 0.0987 - val_accuracy: 0.9567
# Epoch 66/200
# 29/29 [==============================] - 8s 258ms/step - loss: 0.0818 - accuracy: 0.9756 - val_loss: 0.1826 - val_accuracy: 0.9200
# Epoch 67/200
# 29/29 [==============================] - 5s 175ms/step - loss: 0.1100 - accuracy: 0.9567 - val_loss: 0.0725 - val_accuracy: 0.9767
# Epoch 68/200
# 29/29 [==============================] - 6s 208ms/step - loss: 0.0904 - accuracy: 0.9644 - val_loss: 0.0450 - val_accuracy: 0.9867
# Epoch 69/200
# 29/29 [==============================] - 6s 210ms/step - loss: 0.0850 - accuracy: 0.9667 - val_loss: 0.0503 - val_accuracy: 0.9833
# Epoch 70/200
# 29/29 [==============================] - 8s 278ms/step - loss: 0.0581 - accuracy: 0.9778 - val_loss: 0.0754 - val_accuracy: 0.9667
# Epoch 71/200
# 29/29 [==============================] - 6s 212ms/step - loss: 0.0993 - accuracy: 0.9556 - val_loss: 0.0476 - val_accuracy: 0.9800
# Epoch 72/200
# 29/29 [==============================] - 7s 231ms/step - loss: 0.0820 - accuracy: 0.9678 - val_loss: 0.0581 - val_accuracy: 0.9733
# Epoch 73/200
# 29/29 [==============================] - 5s 163ms/step - loss: 0.0874 - accuracy: 0.9611 - val_loss: 0.0882 - val_accuracy: 0.9667
# Epoch 74/200
# 29/29 [==============================] - 6s 198ms/step - loss: 0.0947 - accuracy: 0.9678 - val_loss: 0.0399 - val_accuracy: 0.9900
# Epoch 75/200
# 29/29 [==============================] - 7s 229ms/step - loss: 0.0950 - accuracy: 0.9633 - val_loss: 0.0601 - val_accuracy: 0.9800
# Epoch 76/200
# 29/29 [==============================] - 7s 236ms/step - loss: 0.1189 - accuracy: 0.9567 - val_loss: 0.0495 - val_accuracy: 0.9867
# Epoch 77/200
# 29/29 [==============================] - 5s 161ms/step - loss: 0.0883 - accuracy: 0.9689 - val_loss: 0.1132 - val_accuracy: 0.9500
# Epoch 78/200
# 29/29 [==============================] - 6s 229ms/step - loss: 0.0957 - accuracy: 0.9644 - val_loss: 0.0481 - val_accuracy: 0.9800
# Epoch 79/200
# 29/29 [==============================] - 6s 195ms/step - loss: 0.0826 - accuracy: 0.9711 - val_loss: 0.0706 - val_accuracy: 0.9667
# Epoch 80/200
# 29/29 [==============================] - 5s 165ms/step - loss: 0.0817 - accuracy: 0.9744 - val_loss: 0.0427 - val_accuracy: 0.9967
# Epoch 81/200
# 29/29 [==============================] - 7s 218ms/step - loss: 0.0795 - accuracy: 0.9700 - val_loss: 0.0508 - val_accuracy: 0.9833
# Epoch 82/200
# 29/29 [==============================] - 4s 150ms/step - loss: 0.0748 - accuracy: 0.9767 - val_loss: 0.0571 - val_accuracy: 0.9767
# Epoch 83/200
# 29/29 [==============================] - 6s 205ms/step - loss: 0.1075 - accuracy: 0.9633 - val_loss: 0.1723 - val_accuracy: 0.9267
# Epoch 84/200
# 29/29 [==============================] - 6s 220ms/step - loss: 0.0806 - accuracy: 0.9722 - val_loss: 0.0865 - val_accuracy: 0.9600
# Epoch 85/200
# 29/29 [==============================] - 6s 197ms/step - loss: 0.0882 - accuracy: 0.9656 - val_loss: 0.0465 - val_accuracy: 0.9867
# Epoch 86/200
# 29/29 [==============================] - 7s 227ms/step - loss: 0.1243 - accuracy: 0.9533 - val_loss: 0.1107 - val_accuracy: 0.9667
# Epoch 87/200
# 29/29 [==============================] - 5s 187ms/step - loss: 0.1062 - accuracy: 0.9589 - val_loss: 0.1000 - val_accuracy: 0.9533
# Epoch 88/200
# 29/29 [==============================] - 5s 166ms/step - loss: 0.0734 - accuracy: 0.9722 - val_loss: 0.0850 - val_accuracy: 0.9667
# Epoch 89/200
# 29/29 [==============================] - 6s 198ms/step - loss: 0.0696 - accuracy: 0.9756 - val_loss: 0.0849 - val_accuracy: 0.9667
# Epoch 90/200
# 29/29 [==============================] - 5s 164ms/step - loss: 0.0873 - accuracy: 0.9633 - val_loss: 0.2403 - val_accuracy: 0.9067
# Epoch 91/200
# 29/29 [==============================] - 5s 181ms/step - loss: 0.0811 - accuracy: 0.9722 - val_loss: 0.0548 - val_accuracy: 0.9800
# Epoch 92/200
# 29/29 [==============================] - 6s 196ms/step - loss: 0.0657 - accuracy: 0.9700 - val_loss: 0.0779 - val_accuracy: 0.9667
# Epoch 93/200
# 29/29 [==============================] - 7s 254ms/step - loss: 0.0811 - accuracy: 0.9722 - val_loss: 0.0523 - val_accuracy: 0.9767
# Epoch 94/200
# 29/29 [==============================] - 5s 185ms/step - loss: 0.1240 - accuracy: 0.9522 - val_loss: 0.3723 - val_accuracy: 0.8500
# Epoch 95/200
# 29/29 [==============================] - 5s 159ms/step - loss: 0.0750 - accuracy: 0.9722 - val_loss: 0.0807 - val_accuracy: 0.9667
# Epoch 96/200
# 29/29 [==============================] - 5s 183ms/step - loss: 0.0775 - accuracy: 0.9678 - val_loss: 0.1556 - val_accuracy: 0.9400
# Epoch 97/200
# 29/29 [==============================] - 6s 197ms/step - loss: 0.3590 - accuracy: 0.8889 - val_loss: 0.1633 - val_accuracy: 0.9367
# Epoch 98/200
# 29/29 [==============================] - 5s 167ms/step - loss: 0.2140 - accuracy: 0.9200 - val_loss: 0.1019 - val_accuracy: 0.9600
# Epoch 99/200
# 29/29 [==============================] - 6s 176ms/step - loss: 0.1207 - accuracy: 0.9589 - val_loss: 0.1108 - val_accuracy: 0.9567
# Epoch 100/200
# 29/29 [==============================] - 4s 150ms/step - loss: 0.0909 - accuracy: 0.9689 - val_loss: 0.1788 - val_accuracy: 0.9333
# Epoch 101/200
# 29/29 [==============================] - 6s 202ms/step - loss: 0.0913 - accuracy: 0.9656 - val_loss: 0.1067 - val_accuracy: 0.9533
# Epoch 102/200
# 29/29 [==============================] - 5s 174ms/step - loss: 0.0800 - accuracy: 0.9767 - val_loss: 0.0627 - val_accuracy: 0.9733
# Epoch 103/200
# 29/29 [==============================] - 5s 162ms/step - loss: 0.0842 - accuracy: 0.9722 - val_loss: 0.0588 - val_accuracy: 0.9867
# Epoch 104/200
# 29/29 [==============================] - 4s 151ms/step - loss: 0.0612 - accuracy: 0.9789 - val_loss: 0.0829 - val_accuracy: 0.9600
# Epoch 105/200
# 29/29 [==============================] - 6s 175ms/step - loss: 0.0759 - accuracy: 0.9722 - val_loss: 0.0712 - val_accuracy: 0.9767
# Epoch 106/200
# 29/29 [==============================] - 5s 156ms/step - loss: 0.0743 - accuracy: 0.9722 - val_loss: 0.0520 - val_accuracy: 0.9800
# Epoch 107/200
# 29/29 [==============================] - 5s 166ms/step - loss: 0.0539 - accuracy: 0.9800 - val_loss: 0.1613 - val_accuracy: 0.9333
# Epoch 108/200
# 29/29 [==============================] - 4s 143ms/step - loss: 0.0701 - accuracy: 0.9667 - val_loss: 0.0890 - val_accuracy: 0.9600
# Epoch 109/200
# 29/29 [==============================] - 5s 175ms/step - loss: 0.0720 - accuracy: 0.9811 - val_loss: 0.1218 - val_accuracy: 0.9467
# Epoch 110/200
# 29/29 [==============================] - 7s 236ms/step - loss: 0.0870 - accuracy: 0.9656 - val_loss: 0.0458 - val_accuracy: 0.9867
# Epoch 111/200
# 29/29 [==============================] - 5s 162ms/step - loss: 0.0636 - accuracy: 0.9767 - val_loss: 0.0425 - val_accuracy: 0.9833
# Epoch 112/200
# 29/29 [==============================] - 5s 170ms/step - loss: 0.0670 - accuracy: 0.9767 - val_loss: 0.1013 - val_accuracy: 0.9600
# Epoch 113/200
# 29/29 [==============================] - 4s 132ms/step - loss: 0.0669 - accuracy: 0.9756 - val_loss: 0.0874 - val_accuracy: 0.9633
# Epoch 114/200
# 29/29 [==============================] - 5s 180ms/step - loss: 0.0694 - accuracy: 0.9733 - val_loss: 0.3188 - val_accuracy: 0.8833
# Epoch 115/200
# 29/29 [==============================] - 4s 147ms/step - loss: 0.0800 - accuracy: 0.9767 - val_loss: 0.1333 - val_accuracy: 0.9333
# Epoch 116/200
# 29/29 [==============================] - 4s 138ms/step - loss: 0.0920 - accuracy: 0.9656 - val_loss: 0.1341 - val_accuracy: 0.9467
# Epoch 117/200
# 29/29 [==============================] - 4s 144ms/step - loss: 0.0876 - accuracy: 0.9644 - val_loss: 0.0809 - val_accuracy: 0.9667
# Epoch 118/200
# 29/29 [==============================] - 4s 148ms/step - loss: 0.1030 - accuracy: 0.9589 - val_loss: 0.2347 - val_accuracy: 0.9167
# Epoch 119/200
# 29/29 [==============================] - 7s 259ms/step - loss: 0.0714 - accuracy: 0.9722 - val_loss: 0.0775 - val_accuracy: 0.9733
# Epoch 120/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0989 - accuracy: 0.9633 - val_loss: 0.0804 - val_accuracy: 0.9567
# Epoch 121/200
# 29/29 [==============================] - 5s 167ms/step - loss: 0.0658 - accuracy: 0.9756 - val_loss: 0.1508 - val_accuracy: 0.9333
# Epoch 122/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.0588 - accuracy: 0.9800 - val_loss: 0.1194 - val_accuracy: 0.9567
# Epoch 123/200
# 29/29 [==============================] - 5s 188ms/step - loss: 0.0682 - accuracy: 0.9722 - val_loss: 0.0773 - val_accuracy: 0.9733
# Epoch 124/200
# 29/29 [==============================] - 5s 177ms/step - loss: 0.0556 - accuracy: 0.9800 - val_loss: 0.0968 - val_accuracy: 0.9633
# Epoch 125/200
# 29/29 [==============================] - 4s 141ms/step - loss: 0.0547 - accuracy: 0.9767 - val_loss: 0.0919 - val_accuracy: 0.9633
# Epoch 126/200
# 29/29 [==============================] - 6s 194ms/step - loss: 0.0744 - accuracy: 0.9733 - val_loss: 0.0506 - val_accuracy: 0.9867
# Epoch 127/200
# 29/29 [==============================] - 4s 132ms/step - loss: 0.0584 - accuracy: 0.9756 - val_loss: 0.0771 - val_accuracy: 0.9667
# Epoch 128/200
# 29/29 [==============================] - 4s 139ms/step - loss: 0.0796 - accuracy: 0.9678 - val_loss: 0.0511 - val_accuracy: 0.9867
# Epoch 129/200
# 29/29 [==============================] - 5s 179ms/step - loss: 0.0783 - accuracy: 0.9700 - val_loss: 0.1902 - val_accuracy: 0.9300
# Epoch 130/200
# 29/29 [==============================] - 5s 169ms/step - loss: 0.0849 - accuracy: 0.9656 - val_loss: 0.2222 - val_accuracy: 0.9233
# Epoch 131/200
# 29/29 [==============================] - 3s 113ms/step - loss: 0.0776 - accuracy: 0.9700 - val_loss: 0.1013 - val_accuracy: 0.9467
# Epoch 132/200
# 29/29 [==============================] - 5s 159ms/step - loss: 0.0529 - accuracy: 0.9789 - val_loss: 0.0667 - val_accuracy: 0.9767
# Epoch 133/200
# 29/29 [==============================] - 5s 165ms/step - loss: 0.0564 - accuracy: 0.9767 - val_loss: 0.1158 - val_accuracy: 0.9500
# Epoch 134/200
# 29/29 [==============================] - 4s 142ms/step - loss: 0.0549 - accuracy: 0.9800 - val_loss: 0.0701 - val_accuracy: 0.9833
# Epoch 135/200
# 29/29 [==============================] - 4s 151ms/step - loss: 0.0674 - accuracy: 0.9767 - val_loss: 0.1317 - val_accuracy: 0.9400
# Epoch 136/200
# 29/29 [==============================] - 5s 161ms/step - loss: 0.0792 - accuracy: 0.9711 - val_loss: 0.1565 - val_accuracy: 0.9233
# Epoch 137/200
# 29/29 [==============================] - 4s 154ms/step - loss: 0.0697 - accuracy: 0.9756 - val_loss: 0.0402 - val_accuracy: 0.9867
# Epoch 138/200
# 29/29 [==============================] - 4s 149ms/step - loss: 0.0818 - accuracy: 0.9678 - val_loss: 0.0627 - val_accuracy: 0.9733
# Epoch 139/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.0446 - accuracy: 0.9867 - val_loss: 0.0795 - val_accuracy: 0.9667
# Epoch 140/200
# 29/29 [==============================] - 5s 180ms/step - loss: 0.0530 - accuracy: 0.9778 - val_loss: 0.0501 - val_accuracy: 0.9867
# Epoch 141/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.0538 - accuracy: 0.9778 - val_loss: 0.0471 - val_accuracy: 0.9833
# Epoch 142/200
# 29/29 [==============================] - 4s 127ms/step - loss: 0.0494 - accuracy: 0.9822 - val_loss: 0.1072 - val_accuracy: 0.9633
# Epoch 143/200
# 29/29 [==============================] - 4s 142ms/step - loss: 0.0774 - accuracy: 0.9744 - val_loss: 0.2395 - val_accuracy: 0.8900
# Epoch 144/200
# 29/29 [==============================] - 5s 175ms/step - loss: 0.1026 - accuracy: 0.9600 - val_loss: 0.0535 - val_accuracy: 0.9833
# Epoch 145/200
# 29/29 [==============================] - 4s 151ms/step - loss: 0.0788 - accuracy: 0.9711 - val_loss: 0.0954 - val_accuracy: 0.9533
# Epoch 146/200
# 29/29 [==============================] - 4s 141ms/step - loss: 0.0604 - accuracy: 0.9822 - val_loss: 0.1390 - val_accuracy: 0.9500
# Epoch 147/200
# 29/29 [==============================] - 4s 155ms/step - loss: 0.0641 - accuracy: 0.9700 - val_loss: 0.0771 - val_accuracy: 0.9667
# Epoch 148/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.0477 - accuracy: 0.9789 - val_loss: 0.1411 - val_accuracy: 0.9433
# Epoch 149/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.0417 - accuracy: 0.9800 - val_loss: 0.0409 - val_accuracy: 0.9767
# Epoch 150/200
# 29/29 [==============================] - 4s 131ms/step - loss: 0.0552 - accuracy: 0.9800 - val_loss: 0.0747 - val_accuracy: 0.9733
# Epoch 151/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.0642 - accuracy: 0.9778 - val_loss: 0.1071 - val_accuracy: 0.9567
# Epoch 152/200
# 29/29 [==============================] - 4s 129ms/step - loss: 0.0460 - accuracy: 0.9822 - val_loss: 0.0740 - val_accuracy: 0.9733
# Epoch 153/200
# 29/29 [==============================] - 5s 166ms/step - loss: 0.0586 - accuracy: 0.9756 - val_loss: 0.1302 - val_accuracy: 0.9500
# Epoch 154/200
# 29/29 [==============================] - 4s 149ms/step - loss: 0.0510 - accuracy: 0.9767 - val_loss: 0.0266 - val_accuracy: 0.9967
# Epoch 155/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0641 - accuracy: 0.9833 - val_loss: 0.1494 - val_accuracy: 0.9367
# Epoch 156/200
# 29/29 [==============================] - 4s 127ms/step - loss: 0.2231 - accuracy: 0.9333 - val_loss: 0.2544 - val_accuracy: 0.8900
# Epoch 157/200
# 29/29 [==============================] - 3s 101ms/step - loss: 0.0881 - accuracy: 0.9733 - val_loss: 0.1124 - val_accuracy: 0.9500
# Epoch 158/200
# 29/29 [==============================] - 4s 155ms/step - loss: 0.0633 - accuracy: 0.9744 - val_loss: 0.0659 - val_accuracy: 0.9733
# Epoch 159/200
# 29/29 [==============================] - 3s 98ms/step - loss: 0.0548 - accuracy: 0.9778 - val_loss: 0.0902 - val_accuracy: 0.9633
# Epoch 160/200
# 29/29 [==============================] - 4s 141ms/step - loss: 0.0711 - accuracy: 0.9700 - val_loss: 0.0379 - val_accuracy: 0.9933
# Epoch 161/200
# 29/29 [==============================] - 5s 167ms/step - loss: 0.0646 - accuracy: 0.9756 - val_loss: 0.0291 - val_accuracy: 0.9933
# Epoch 162/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.0519 - accuracy: 0.9811 - val_loss: 0.1727 - val_accuracy: 0.9367
# Epoch 163/200
# 29/29 [==============================] - 4s 130ms/step - loss: 0.0637 - accuracy: 0.9767 - val_loss: 0.0368 - val_accuracy: 0.9833
# Epoch 164/200
# 29/29 [==============================] - 4s 130ms/step - loss: 0.0719 - accuracy: 0.9733 - val_loss: 0.0568 - val_accuracy: 0.9800
# Epoch 165/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.0456 - accuracy: 0.9856 - val_loss: 0.0861 - val_accuracy: 0.9700
# Epoch 166/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.0465 - accuracy: 0.9856 - val_loss: 0.0448 - val_accuracy: 0.9833
# Epoch 167/200
# 29/29 [==============================] - 5s 163ms/step - loss: 0.0437 - accuracy: 0.9833 - val_loss: 0.0722 - val_accuracy: 0.9733
# Epoch 168/200
# 29/29 [==============================] - 5s 166ms/step - loss: 0.0448 - accuracy: 0.9800 - val_loss: 0.0551 - val_accuracy: 0.9833
# Epoch 169/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.0519 - accuracy: 0.9800 - val_loss: 0.0365 - val_accuracy: 0.9800
# Epoch 170/200
# 29/29 [==============================] - 4s 140ms/step - loss: 0.0439 - accuracy: 0.9811 - val_loss: 0.0621 - val_accuracy: 0.9767
# Epoch 171/200
# 29/29 [==============================] - 4s 131ms/step - loss: 0.0811 - accuracy: 0.9756 - val_loss: 0.0647 - val_accuracy: 0.9733
# Epoch 172/200
# 29/29 [==============================] - 4s 143ms/step - loss: 0.0697 - accuracy: 0.9733 - val_loss: 0.2582 - val_accuracy: 0.9067
# Epoch 173/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0946 - accuracy: 0.9644 - val_loss: 0.0937 - val_accuracy: 0.9633
# Epoch 174/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0475 - accuracy: 0.9822 - val_loss: 0.0689 - val_accuracy: 0.9767
# Epoch 175/200
# 29/29 [==============================] - 4s 129ms/step - loss: 0.0377 - accuracy: 0.9856 - val_loss: 0.0575 - val_accuracy: 0.9800
# Epoch 176/200
# 29/29 [==============================] - 4s 126ms/step - loss: 0.0577 - accuracy: 0.9789 - val_loss: 0.0707 - val_accuracy: 0.9633
# Epoch 177/200
# 29/29 [==============================] - 3s 112ms/step - loss: 0.0428 - accuracy: 0.9833 - val_loss: 0.1059 - val_accuracy: 0.9600
# Epoch 178/200
# 29/29 [==============================] - 3s 99ms/step - loss: 0.0655 - accuracy: 0.9700 - val_loss: 0.0638 - val_accuracy: 0.9700
# Epoch 179/200
# 29/29 [==============================] - 4s 131ms/step - loss: 0.0780 - accuracy: 0.9678 - val_loss: 0.1352 - val_accuracy: 0.9567
# Epoch 180/200
# 29/29 [==============================] - 3s 99ms/step - loss: 0.0431 - accuracy: 0.9833 - val_loss: 0.0393 - val_accuracy: 0.9833
# Epoch 181/200
# 29/29 [==============================] - 4s 146ms/step - loss: 0.0338 - accuracy: 0.9889 - val_loss: 0.0352 - val_accuracy: 0.9867
# Epoch 182/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.0489 - accuracy: 0.9800 - val_loss: 0.0429 - val_accuracy: 0.9833
# Epoch 183/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.0738 - accuracy: 0.9756 - val_loss: 0.1065 - val_accuracy: 0.9500
# Epoch 184/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.0506 - accuracy: 0.9800 - val_loss: 0.0290 - val_accuracy: 0.9967
# Epoch 185/200
# 29/29 [==============================] - 3s 117ms/step - loss: 0.0462 - accuracy: 0.9811 - val_loss: 0.0371 - val_accuracy: 0.9867
# Epoch 186/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.0468 - accuracy: 0.9800 - val_loss: 0.1221 - val_accuracy: 0.9567
# Epoch 187/200
# 29/29 [==============================] - 3s 113ms/step - loss: 0.0571 - accuracy: 0.9767 - val_loss: 0.0569 - val_accuracy: 0.9733
# Epoch 188/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.0636 - accuracy: 0.9722 - val_loss: 0.0834 - val_accuracy: 0.9700
# Epoch 189/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.0374 - accuracy: 0.9856 - val_loss: 0.1253 - val_accuracy: 0.9500
# Epoch 190/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0791 - accuracy: 0.9711 - val_loss: 0.0422 - val_accuracy: 0.9867
# Epoch 191/200
# 29/29 [==============================] - 4s 143ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 0.2138 - val_accuracy: 0.9300
# Epoch 192/200
# 29/29 [==============================] - 3s 113ms/step - loss: 0.0784 - accuracy: 0.9744 - val_loss: 0.1895 - val_accuracy: 0.9333
# Epoch 193/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0587 - accuracy: 0.9778 - val_loss: 0.0758 - val_accuracy: 0.9700
# Epoch 194/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.0434 - accuracy: 0.9800 - val_loss: 0.0296 - val_accuracy: 0.9900
# Epoch 195/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0486 - accuracy: 0.9811 - val_loss: 0.0536 - val_accuracy: 0.9767
# Epoch 196/200
# 29/29 [==============================] - 3s 97ms/step - loss: 0.0558 - accuracy: 0.9822 - val_loss: 0.0956 - val_accuracy: 0.9633
# Epoch 197/200
# 29/29 [==============================] - 2s 75ms/step - loss: 0.0869 - accuracy: 0.9678 - val_loss: 0.0481 - val_accuracy: 0.9833
# Epoch 198/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.0679 - accuracy: 0.9767 - val_loss: 0.0326 - val_accuracy: 0.9867
# Epoch 199/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0724 - accuracy: 0.9678 - val_loss: 0.0327 - val_accuracy: 0.9900
# Epoch 200/200
# 29/29 [==============================] - 4s 132ms/step - loss: 0.0642 - accuracy: 0.9778 - val_loss: 0.1726 - val_accuracy: 0.9267

# %% [markdown]
# # Check best weight validation data percentance

# %%
def bestWeightModelEvaluate(model, weight_path, data):
  cp_model = tf.keras.models.clone_model(model)
  cp_model.compile(
      loss = tf.keras.losses.CategoricalCrossentropy(),
      optimizer = tf.keras.optimizers.Adam(),
      metrics = ['accuracy']
  )
  cp_model.load_weights(weight_path)
  cp_model.evaluate(data)

# %%
bestWeightModelEvaluate(
    model = model,
    weight_path= checkpoint_path,
    data = valid_data
)
# Out:
# 10/10 [==============================] - 2s 27ms/step - loss: 0.1178 - accuracy: 0.9500

# %%
bestWeightModelEvaluate(
    model = model,
    weight_path= checkpoint_path,
    data = test_data
)
# Out:
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0427 - accuracy: 0.9967

# %% [markdown]
# # Download pretrain model

# %%
! wget "https://github.com/HSAkash/Potato-Leaf-Disease-Dataset/raw/main/potato_pretrain_model.h5"
# Out:
# --2022-08-13 02:15:58--  https://github.com/HSAkash/Potato-Leaf-Disease-Dataset/raw/main/potato_pretrain_model.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/HSAkash/Potato-Leaf-Disease-Dataset/main/potato_pretrain_model.h5 [following]
# --2022-08-13 02:15:58--  https://raw.githubusercontent.com/HSAkash/Potato-Leaf-Disease-Dataset/main/potato_pretrain_model.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 849224 (829K) [application/octet-stream]
# Saving to: ‘potato_pretrain_model.h5’
#
# potato_pretrain_mod 100%[===================>] 829.32K  --.-KB/s    in 0.07s
#
# 2022-08-13 02:15:58 (11.5 MB/s) - ‘potato_pretrain_model.h5’ saved [849224/849224]

# %% [markdown]
# ## Load model

# %%
load_model = tf.keras.models.load_model("potato_pretrain_model.h5")

# %% [markdown]
# ## summary of load data

# %%
load_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# data_augmentation (Sequentia (None, None, None, 3)     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 60)    1680
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, None, None, 60)    0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 60)    32460
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, None, None, 60)    0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 60)    32460
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, None, None, 60)    0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 60)                0
# _________________________________________________________________
# output_layers (Dense)        (None, 3)                 183
# =================================================================
# Total params: 66,783
# Trainable params: 66,783
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Main model summary.
# main model and load model are save

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# data_augmentation (Sequentia (None, None, None, 3)     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 60)    1680
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, None, None, 60)    0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 60)    32460
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, None, None, 60)    0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 60)    32460
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, None, None, 60)    0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 60)                0
# _________________________________________________________________
# output_layers (Dense)        (None, 3)                 183
# =================================================================
# Total params: 66,783
# Trainable params: 66,783
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluate load model with valid data and test_data

# %%
load_model.evaluate(test_data)
# Out:
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0424 - accuracy: 0.9967
# [0.042373038828372955, 0.996666669845581]

# %%
load_model.evaluate(valid_data)
# Out:
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0707 - accuracy: 0.9800
# [0.07074113935232162, 0.9800000190734863]

# %% [markdown]
# ## Predicting the values

# %%
import numpy as np
predictions = load_model.predict(test_data)
predictions = np.argmax(predictions, axis=-1)
predictions.shape
# Out:
# (300,)

# %% [markdown]
# ## Visualize prediction

# %%
plt.figure(figsize=(12,12))
for image_batch,label_batch in test_data.take(1):
    for i in range(0,8):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        true_class = class_names[np.argmax(label_batch[i])]
        predict_class = class_names[predictions[i]]
        title = f"""True:{true_class}\n Predict:{predict_class}"""
        plt.title(title, color='g' if true_class==predict_class else 'r')
        plt.axis("off")
